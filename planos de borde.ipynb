# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from pymatgen import Molecule
from pymatgen.io.xyz import XYZ

# %matplotlib inline

# %%
a = np.array([[1],[0]])
b = np.array([[0],[1]])

Mmax=20
Nmax=20
R = 20

# %%
caja = []
etiq = []

for n in range(-Mmax,Mmax):
    for m in range(-Nmax,Nmax):
        vector = m*a + n*b
        ejez = np.append(vector, 0)
        if ejez[1] > 0:
            caja.append(ejez)
            etiq.append("H")
        
plano = Molecule(etiq, caja)
print (caja)
# Out:
# [array([-20,   1,   0]), array([-19,   1,   0]), array([-18,   1,   0]), array([-17,   1,   0]), array([-16,   1,   0]), array([-15,   1,   0]), array([-14,   1,   0]), array([-13,   1,   0]), array([-12,   1,   0]), array([-11,   1,   0]), array([-10,   1,   0]), array([-9,  1,  0]), array([-8,  1,  0]), array([-7,  1,  0]), array([-6,  1,  0]), array([-5,  1,  0]), array([-4,  1,  0]), array([-3,  1,  0]), array([-2,  1,  0]), array([-1,  1,  0]), array([0, 1, 0]), array([1, 1, 0]), array([2, 1, 0]), array([3, 1, 0]), array([4, 1, 0]), array([5, 1, 0]), array([6, 1, 0]), array([7, 1, 0]), array([8, 1, 0]), array([9, 1, 0]), array([10,  1,  0]), array([11,  1,  0]), array([12,  1,  0]), array([13,  1,  0]), array([14,  1,  0]), array([15,  1,  0]), array([16,  1,  0]), array([17,  1,  0]), array([18,  1,  0]), array([19,  1,  0]), array([-20,   2,   0]), array([-19,   2,   0]), array([-18,   2,   0]), array([-17,   2,   0]), array([-16,   2,   0]), array([-15,   2,   0]), array([-14,   2,   0]), array([-13,   2,   0]), array([-12,   2,   0]), array([-11,   2,   0]), array([-10,   2,   0]), array([-9,  2,  0]), array([-8,  2,  0]), array([-7,  2,  0]), array([-6,  2,  0]), array([-5,  2,  0]), array([-4,  2,  0]), array([-3,  2,  0]), array([-2,  2,  0]), array([-1,  2,  0]), array([0, 2, 0]), array([1, 2, 0]), array([2, 2, 0]), array([3, 2, 0]), array([4, 2, 0]), array([5, 2, 0]), array([6, 2, 0]), array([7, 2, 0]), array([8, 2, 0]), array([9, 2, 0]), array([10,  2,  0]), array([11,  2,  0]), array([12,  2,  0]), array([13,  2,  0]), array([14,  2,  0]), array([15,  2,  0]), array([16,  2,  0]), array([17,  2,  0]), array([18,  2,  0]), array([19,  2,  0]), array([-20,   3,   0]), array([-19,   3,   0]), array([-18,   3,   0]), array([-17,   3,   0]), array([-16,   3,   0]), array([-15,   3,   0]), array([-14,   3,   0]), array([-13,   3,   0]), array([-12,   3,   0]), array([-11,   3,   0]), array([-10,   3,   0]), array([-9,  3,  0]), array([-8,  3,  0]), array([-7,  3,  0]), array([-6,  3,  0]), array([-5,  3,  0]), array([-4,  3,  0]), array([-3,  3,  0]), array([-2,  3,  0]), array([-1,  3,  0]), array([0, 3, 0]), array([1, 3, 0]), array([2, 3, 0]), array([3, 3, 0]), array([4, 3, 0]), array([5, 3, 0]), array([6, 3, 0]), array([7, 3, 0]), array([8, 3, 0]), array([9, 3, 0]), array([10,  3,  0]), array([11,  3,  0]), array([12,  3,  0]), array([13,  3,  0]), array([14,  3,  0]), array([15,  3,  0]), array([16,  3,  0]), array([17,  3,  0]), array([18,  3,  0]), array([19,  3,  0]), array([-20,   4,   0]), array([-19,   4,   0]), array([-18,   4,   0]), array([-17,   4,   0]), array([-16,   4,   0]), array([-15,   4,   0]), array([-14,   4,   0]), array([-13,   4,   0]), array([-12,   4,   0]), array([-11,   4,   0]), array([-10,   4,   0]), array([-9,  4,  0]), array([-8,  4,  0]), array([-7,  4,  0]), array([-6,  4,  0]), array([-5,  4,  0]), array([-4,  4,  0]), array([-3,  4,  0]), array([-2,  4,  0]), array([-1,  4,  0]), array([0, 4, 0]), array([1, 4, 0]), array([2, 4, 0]), array([3, 4, 0]), array([4, 4, 0]), array([5, 4, 0]), array([6, 4, 0]), array([7, 4, 0]), array([8, 4, 0]), array([9, 4, 0]), array([10,  4,  0]), array([11,  4,  0]), array([12,  4,  0]), array([13,  4,  0]), array([14,  4,  0]), array([15,  4,  0]), array([16,  4,  0]), array([17,  4,  0]), array([18,  4,  0]), array([19,  4,  0]), array([-20,   5,   0]), array([-19,   5,   0]), array([-18,   5,   0]), array([-17,   5,   0]), array([-16,   5,   0]), array([-15,   5,   0]), array([-14,   5,   0]), array([-13,   5,   0]), array([-12,   5,   0]), array([-11,   5,   0]), array([-10,   5,   0]), array([-9,  5,  0]), array([-8,  5,  0]), array([-7,  5,  0]), array([-6,  5,  0]), array([-5,  5,  0]), array([-4,  5,  0]), array([-3,  5,  0]), array([-2,  5,  0]), array([-1,  5,  0]), array([0, 5, 0]), array([1, 5, 0]), array([2, 5, 0]), array([3, 5, 0]), array([4, 5, 0]), array([5, 5, 0]), array([6, 5, 0]), array([7, 5, 0]), array([8, 5, 0]), array([9, 5, ...

# %%
theta = np.radians(30)

r = np.array(( (np.cos(theta), -np.sin(theta)),
               (np.sin(theta),  np.cos(theta)) ))

print('rotation matrix:')
print(r)
# Out:
# rotation matrix:
# [[ 0.8660254 -0.5      ]
#  [ 0.5        0.8660254]]

# %%
caja = []
etiq = []

for n in range(-Mmax,Mmax):
    for m in range(-Nmax,Nmax):
        vector = m*a + n*b
        rot = r.dot(vector)
        ejez = np.append(rot, 0)
        if ejez[1] < 0:
            caja.append(ejez)
            etiq.append("H")

planorot = Molecule(etiq, caja)
print (caja)
# Out:
# [array([ -7.32050808, -27.32050808,   0.        ]), array([ -6.45448267, -26.82050808,   0.        ]), array([ -5.58845727, -26.32050808,   0.        ]), array([ -4.72243186, -25.82050808,   0.        ]), array([ -3.85640646, -25.32050808,   0.        ]), array([ -2.99038106, -24.82050808,   0.        ]), array([ -2.12435565, -24.32050808,   0.        ]), array([ -1.25833025, -23.82050808,   0.        ]), array([ -0.39230485, -23.32050808,   0.        ]), array([  0.47372056, -22.82050808,   0.        ]), array([  1.33974596, -22.32050808,   0.        ]), array([  2.20577137, -21.82050808,   0.        ]), array([  3.07179677, -21.32050808,   0.        ]), array([  3.93782217, -20.82050808,   0.        ]), array([  4.80384758, -20.32050808,   0.        ]), array([  5.66987298, -19.82050808,   0.        ]), array([  6.53589838, -19.32050808,   0.        ]), array([  7.40192379, -18.82050808,   0.        ]), array([  8.26794919, -18.32050808,   0.        ]), array([  9.1339746 , -17.82050808,   0.        ]), array([ 10.        , -17.32050808,   0.        ]), array([ 10.8660254 , -16.82050808,   0.        ]), array([ 11.73205081, -16.32050808,   0.        ]), array([ 12.59807621, -15.82050808,   0.        ]), array([ 13.46410162, -15.32050808,   0.        ]), array([ 14.33012702, -14.82050808,   0.        ]), array([ 15.19615242, -14.32050808,   0.        ]), array([ 16.06217783, -13.82050808,   0.        ]), array([ 16.92820323, -13.32050808,   0.        ]), array([ 17.79422863, -12.82050808,   0.        ]), array([ 18.66025404, -12.32050808,   0.        ]), array([ 19.52627944, -11.82050808,   0.        ]), array([ 20.39230485, -11.32050808,   0.        ]), array([ 21.25833025, -10.82050808,   0.        ]), array([ 22.12435565, -10.32050808,   0.        ]), array([22.99038106, -9.82050808,  0.        ]), array([23.85640646, -9.32050808,  0.        ]), array([24.72243186, -8.82050808,  0.        ]), array([25.58845727, -8.32050808,  0.        ]), array([26.45448267, -7.82050808,  0.        ]), array([ -7.82050808, -26.45448267,   0.        ]), array([ -6.95448267, -25.95448267,   0.        ]), array([ -6.08845727, -25.45448267,   0.        ]), array([ -5.22243186, -24.95448267,   0.        ]), array([ -4.35640646, -24.45448267,   0.        ]), array([ -3.49038106, -23.95448267,   0.        ]), array([ -2.62435565, -23.45448267,   0.        ]), array([ -1.75833025, -22.95448267,   0.        ]), array([ -0.89230485, -22.45448267,   0.        ]), array([ -0.02627944, -21.95448267,   0.        ]), array([  0.83974596, -21.45448267,   0.        ]), array([  1.70577137, -20.95448267,   0.        ]), array([  2.57179677, -20.45448267,   0.        ]), array([  3.43782217, -19.95448267,   0.        ]), array([  4.30384758, -19.45448267,   0.        ]), array([  5.16987298, -18.95448267,   0.        ]), array([  6.03589838, -18.45448267,   0.        ]), array([  6.90192379, -17.95448267,   0.        ]), array([  7.76794919, -17.45448267,   0.        ]), array([  8.6339746 , -16.95448267,   0.        ]), array([  9.5       , -16.45448267,   0.        ]), array([ 10.3660254 , -15.95448267,   0.        ]), array([ 11.23205081, -15.45448267,   0.        ]), array([ 12.09807621, -14.95448267,   0.        ]), array([ 12.96410162, -14.45448267,   0.        ]), array([ 13.83012702, -13.95448267,   0.        ]), array([ 14.69615242, -13.45448267,   0.        ]), array([ 15.56217783, -12.95448267,   0.        ]), array([ 16.42820323, -12.45448267,   0.        ]), array([ 17.29422863, -11.95448267,   0.        ]), array([ 18.16025404, -11.45448267,   0.        ]), array([ 19.02627944, -10.95448267,   0.        ]), array([ 19.89230485, -10.45448267,   0.        ]), array([20.75833025, -9.95448267,  0.        ]), array([21.62435565, -9.45448267,  0.        ]), array([22.49038106, -8.95448267,  0.        ]), array([23.35640646, -8.45448267,  0.        ]), array([24.22243186, -7.95448267,  0.        ]), array([25.08845727, -7.45448267,  0.        ]), arr ...

# %%
xyz = XYZ(plano)
xyz.write_file("plano.xyz")

# %%
xyz = XYZ(planorot)
xyz.write_file("planorot.xyz")
